# %%
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers.core import Dense
from tensorflow import keras


# the four different states of the XOR gate
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# the four expected results in the same order
target_data = np.array([[0],[1],[1],[0]], "float32")

model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='relu'))

# opt=keras.optimizers.SGD(learning_rate=0.03)
# opt=keras.optimizers.Adam(learning_rate=0.15)

model.compile(loss='mean_squared_error',
              optimizer='Adam',
              metrics=['binary_accuracy'])

with tf.device('/gpu:0'):
    model.fit(training_data, target_data, epochs=50, verbose=2)

print(model.predict(training_data).round())
# Out:
# Epoch 1/50
# 1/1 - 0s - loss: 0.2102 - binary_accuracy: 0.5000 - 208ms/epoch - 208ms/step
# Epoch 2/50
# 1/1 - 0s - loss: 0.2074 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 0.2047 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 0.2020 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 0.1994 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 0.1968 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 0.1942 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 0.1915 - binary_accuracy: 0.5000 - 3ms/epoch - 3ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 0.1890 - binary_accuracy: 0.5000 - 2ms/epoch - 2ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 0.1864 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 0.1842 - binary_accuracy: 0.5000 - 4ms/epoch - 4ms/step
# Epoch 12/50
# ...

# %% [markdown]
# Teniendo una modificación pequeña, solamente modificando solamente las funciones de activación de 'sigmoid' a 'relu' y la utilización de la GPU para el entrenamiento del modelo, se tiene que en vez de unas aproximadas 800 epocas apra obtener una precision binaria de 100%, este ahora lo resuelve en menos de 100 epocas, siendo la corrida la cual se guardo, en menos de 50.
